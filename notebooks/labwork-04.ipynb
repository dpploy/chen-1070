# %% [markdown]
# ChEn-1070: Introduction to Chemical Engineering Spring 2019 UMass Lowell; Profs. Manohar and de Almeida **05Mar2019**
#
# # Laboratory Work 04 12Feb2019

# %% [markdown]
# ### Name: `your name`

# %% [markdown]
# ### Rubric for each assignment:
#
# |         Context                    |  Points |
# | -----------------------     | ------- |
# | Precision of the answer     |   80%   |
# | Answer Markdown readability |   10%   |
# | Code readability            |   10%   |

# %% [markdown]
# ### <span style="color:red">Guidance:</span>
#  +  <span style="color:red">
#     Save your work frequently to a file locally to your computer.
#     </span>
#  +  <span style="color:red">
#     During your work and before submitting the final version do: `Kernel` -> `Restart & Run All`, to verify your notebook runs correctly.
#     </span>
#  +  <span style="color:red">
#     Save your file again.
#     </span>

# %% [markdown]
# ## <span style="color:blue">Assignment 1 (20 pts).</span>
# ### <span style="color:blue">Convert 235.78 $\mu$m to centimeter and compute the conversion factor</span>

# %%
import scipy.constants as const

value = 235.78 # um
converted = 
micro_to_centi = 
print('converted [cm] = ',converted)
print('multiplying factor = ',micro_to_centi)
# Out:
# converted [cm] =  0.023577999999999998
# multiplying factor =  9.999999999999999e-05

# %% [markdown]
# ## <span style="color:blue">Assignment 2 (20 pts).</span>
# ### <span style="color:blue">Convert 38.57 gallons to liter and compute the conversion factor.</span>

# %% [markdown]
# ## <span style="color:blue">Assignment 3 (20 pts).</span>
# ### <span style="color:blue">Convert 1345.789 psi to bar and compute the conversion factor.</span>

# %% [markdown]
# ## <span style="color:blue">Assignment 4 (20 pts).</span>
# ### <span style="color:blue">Convert 784.12 K to Celsius and compute the conversion factor.</span>

# %% [markdown]
# ## <span style="color:blue">Assignment 5 (20 pts).</span>
# ### <span style="color:blue">Compute the total energy in kilo-calories per 24 hours for a heat source that produces 1.13 Joule per second. Develop your code following your thought process and explain it in a Markdown cell below the code.</span>

# %% [markdown]
# **Explain here:**
